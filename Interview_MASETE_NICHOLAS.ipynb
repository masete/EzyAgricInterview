# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-68b48205757c> in <module>
#       2 import plotly.graph_objects as go
#       3 import pandas as pd
# ----> 4 from shapely.geometry import Point
#       5 import geopandas as gpd
#       6 from geopandas import GeoDataFrame
#
# ModuleNotFoundError: No module named 'shapely'

# %%
df = pd.read_csv('Interview Challenge.csv')

# %%
df.head()
# Out:
#                                  id  latitudes/0  latitudes/1  latitudes/2  \
# 0  7590cf21d1a446e3b07c92912a4a3c44     2.980511     2.980595     2.980763
# 1  c7b3fde63650440abbaaecec33e30bfa     2.965254     2.965177     2.965122
# 2  ef2b90b7ff804894a8413477cdfa0e86     2.961134     2.961096     2.961096
# 3  604a8069c5bb4620b7394a7ec5603c18     2.961075     2.961193     2.960932
# 4  9848201f11824ca5a7639aee61152122     2.960971     2.961101     2.961128
#
#    latitudes/3  longitudes/0  longitudes/1  longitudes/2  longitudes/3  \
# 0     2.980530     32.531686     32.531705     32.531327     32.531240
# 1     2.966003     32.249756     32.250017     32.250278     32.250418
# 2     2.961162     32.240426     32.240401     32.240401     32.240312
# 3     2.960932     32.240455     32.240537     32.240490     32.240490
# 4     2.961035     32.240536     32.240386     32.240551     32.240573
#
#    latitudes/4  longitudes/4  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...

# %%
df1 = df.drop(['Unnamed: 11', 'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15'], axis = 1)

# %%
df1.head()
# Out:
#                                  id  latitudes/0  latitudes/1  latitudes/2  \
# 0  7590cf21d1a446e3b07c92912a4a3c44     2.980511     2.980595     2.980763
# 1  c7b3fde63650440abbaaecec33e30bfa     2.965254     2.965177     2.965122
# 2  ef2b90b7ff804894a8413477cdfa0e86     2.961134     2.961096     2.961096
# 3  604a8069c5bb4620b7394a7ec5603c18     2.961075     2.961193     2.960932
# 4  9848201f11824ca5a7639aee61152122     2.960971     2.961101     2.961128
#
#    latitudes/3  longitudes/0  longitudes/1  longitudes/2  longitudes/3  \
# 0     2.980530     32.531686     32.531705     32.531327     32.531240
# 1     2.966003     32.249756     32.250017     32.250278     32.250418
# 2     2.961162     32.240426     32.240401     32.240401     32.240312
# 3     2.960932     32.240455     32.240537     32.240490     32.240490
# 4     2.961035     32.240536     32.240386     32.240551     32.240573
#
#    latitudes/4  longitudes/4
# 0     2.980515     32.531657
# ...

# %%
df1.columns
# Out:
# Index(['id', 'latitudes/0', 'latitudes/1', 'latitudes/2', 'latitudes/3',
#        'longitudes/0', 'longitudes/1', 'longitudes/2', 'longitudes/3',
#        'latitudes/4', 'longitudes/4'],
#       dtype='object')

# %%
df1 = df1.rename(columns={'id': 'id', 'latitudes/0' : 'latitudes_0', 'latitudes/1': 'latitudes_1', 'latitudes/2': 'latitudes_2', 'latitudes/3': 'latitudes_3',
       'longitudes/0' :'longitudes_0', 'longitudes/1':'longitudes_1', 'longitudes/2':'longitudes_2', 'longitudes/3':'longitudes_3',
       'latitudes/4': 'latitudes_4', 'longitudes/4':'longitudes_4'})

# %%
df1.head()
# Out:
#                                  id  latitudes_0  latitudes_1  latitudes_2  \
# 0  7590cf21d1a446e3b07c92912a4a3c44     2.980511     2.980595     2.980763
# 1  c7b3fde63650440abbaaecec33e30bfa     2.965254     2.965177     2.965122
# 2  ef2b90b7ff804894a8413477cdfa0e86     2.961134     2.961096     2.961096
# 3  604a8069c5bb4620b7394a7ec5603c18     2.961075     2.961193     2.960932
# 4  9848201f11824ca5a7639aee61152122     2.960971     2.961101     2.961128
#
#    latitudes_3  longitudes_0  longitudes_1  longitudes_2  longitudes_3  \
# 0     2.980530     32.531686     32.531705     32.531327     32.531240
# 1     2.966003     32.249756     32.250017     32.250278     32.250418
# 2     2.961162     32.240426     32.240401     32.240401     32.240312
# 3     2.960932     32.240455     32.240537     32.240490     32.240490
# 4     2.961035     32.240536     32.240386     32.240551     32.240573
#
#    latitudes_4  longitudes_4
# 0     2.980515     32.531657
# ...

# %%
df1.columns
# Out:
# Index(['id', 'latitudes_0', 'latitudes_1', 'latitudes_2', 'latitudes_3',
#        'longitudes_0', 'longitudes_1', 'longitudes_2', 'longitudes_3',
#        'latitudes_4', 'longitudes_4'],
#       dtype='object')

# %%
column_names = ['id', 'latitudes_0', 'latitudes_1', 'latitudes_2', 'latitudes_3','latitudes_4',
       'longitudes_0', 'longitudes_1', 'longitudes_2', 'longitudes_3'
       , 'longitudes_4']

# %%
data = df1.reindex(columns=column_names)

# %%
data.head()
# Out:
#                                  id  latitudes_0  latitudes_1  latitudes_2  \
# 0  7590cf21d1a446e3b07c92912a4a3c44     2.980511     2.980595     2.980763
# 1  c7b3fde63650440abbaaecec33e30bfa     2.965254     2.965177     2.965122
# 2  ef2b90b7ff804894a8413477cdfa0e86     2.961134     2.961096     2.961096
# 3  604a8069c5bb4620b7394a7ec5603c18     2.961075     2.961193     2.960932
# 4  9848201f11824ca5a7639aee61152122     2.960971     2.961101     2.961128
#
#    latitudes_3  latitudes_4  longitudes_0  longitudes_1  longitudes_2  \
# 0     2.980530     2.980515     32.531686     32.531705     32.531327
# 1     2.966003     2.965983     32.249756     32.250017     32.250278
# 2     2.961162     2.960957     32.240426     32.240401     32.240401
# 3     2.960932     2.961053     32.240455     32.240537     32.240490
# 4     2.961035     2.960998     32.240536     32.240386     32.240551
#
#    longitudes_3  longitudes_4
# 0     32.531240     32.531657
# 1     32.250418     32.249870
# ...

# %%
geometry = [Point(xy) for xy in zip(data['longitude'], data['latitude'])]
gdf = GeoDataFrame(data, geometry=geometry)   

#this is a simple map that goes with geopandas
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15);

# %%
# fig = px.choropleth(df1, geojson=id, locations='latitudes/0', color='latitudes/0',
#                            color_continuous_scale="Viridis",
#                            range_color=(0, 12),
#                            scope="world",
#                            labels={'Gargens':'Garden distribution on a map'}
#                           )
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# fig.show()
